# %% [markdown]
# # COVID-19 country growth analysis

# %% [markdown]
# Compares the growth rate of COVID-19 infections within countries.
#
# Important to note:
#
#  - Countries often see a high growth rate in the initial 2-3 weeks due to travellers returning from overseas who (at least in Australia) tend to make up the majority of cases
#  - Community transmission is low early and takes hold after this initial 2-3 week period. Countries that are able to slow the community transmission early (by controlling returned travellers through quarantine etc.) have proved most effective in controlling the infection rate
#  - It is commonly accepted that infection rates are higher than those reported due to:
#
#   a) lack of availability of testing kits;
#
#   b) strict criteria on who is able to receive a test (due to lack of availability of kits);
#
#   c) asymptomatic carriers of the virus (some predictions are around 20%)

# %%
# wrangling tools
import numpy as np
import pandas as pd
import datetime as dt
# viz tools
import plotnine as p9
from mizani.breaks import date_breaks
from mizani.formatters import date_format

# %%
#import sys
#!{sys.executable} -m pip install plotnine

# %%
df_c19_all = pd.read_csv('novel-corona-virus-2019-dataset/covid_19_data.csv')
df_c19_all.tail()
# Out:
#          SNo ObservationDate Province/State  Country/Region  \
# 10353  10354      03/30/2020        Wyoming              US
# 10354  10355      03/30/2020       Xinjiang  Mainland China
# 10355  10356      03/30/2020          Yukon          Canada
# 10356  10357      03/30/2020         Yunnan  Mainland China
# 10357  10358      03/30/2020       Zhejiang  Mainland China
#
#                Last Update  Confirmed  Deaths  Recovered
# 10353  2020-03-30 22:58:55       94.0     0.0        0.0
# 10354  2020-03-30 22:58:55       76.0     3.0       73.0
# 10355  2020-03-30 22:58:55        4.0     0.0        0.0
# 10356  2020-03-30 22:58:55      180.0     2.0      172.0
# 10357  2020-03-30 22:58:55     1255.0     1.0     1225.0

# %%
# initial cleaning, global variables

df_c19_all['ObservationDate'] = pd.to_datetime(df_c19_all['ObservationDate'])
df_c19_all.rename(columns={'Country/Region':'Country'}, inplace=True)

latest_date = str(dt.date.today() - dt.timedelta(days=2))

# %% [markdown]
# ## Analysis of growth patterns since 100 cases
# #### For countries > 1,000 cases

# %%
def latest_over_thresh(df, num_inf):
    
    '''
    Returns a df with the data for all countries that, as of the latest date in the data,
    have over a certain amount of total infections (num_inf, we'll start with 1,000)
    '''
    
    latest_date = str(dt.date.today() - dt.timedelta(days=2))
    
    df_latest = df[df['ObservationDate'] == latest_date]
    
    country_list = list(df_latest[df_latest['Confirmed'] >= num_inf].Country)
    df_over_thresh = df[df['Country'].isin(country_list)]
    df_over_thresh = df_over_thresh[['ObservationDate','Country','Confirmed','Deaths', 'Recovered']].groupby(['Country', 'ObservationDate']).sum()
    #df_over_thresh.sort_values('Confirmed', ascending=False, inplace=True)
    df_over_thresh.reset_index(inplace=True)
    
    return(df_over_thresh)

# %%
'''
test_df =   (    
        df_c19_all
        .query('ObservationDate == "2020-03-28"')
        .filter(items=['ObservationDate', 'Country'])
        .sort_values('ObservationDate', ascending=False)
        .reset_index(drop=True)
    )
'''
# Out:
#     ObservationDate         Country
# 0        2020-03-28     Afghanistan
# 1        2020-03-28              UK
# 2        2020-03-28  Mainland China
# 3        2020-03-28  Mainland China
# 4        2020-03-28              US
# ..              ...             ...
# 306      2020-03-28       Mauritius
# 307      2020-03-28      Mauritania
# 308      2020-03-28           Malta
# 309      2020-03-28            Mali
# 310      2020-03-28  Mainland China
#
# [311 rows x 2 columns]

# %%
df_largest_inf_rates = latest_over_thresh(df_c19_all, 1000)
df_largest_inf_rates
# Out:
#         Country ObservationDate  Confirmed  Deaths  Recovered
# 0     Australia      2020-01-23        0.0     0.0        0.0
# 1     Australia      2020-01-25        4.0     0.0        0.0
# 2     Australia      2020-01-26        4.0     0.0        0.0
# 3     Australia      2020-01-27        5.0     0.0        0.0
# 4     Australia      2020-01-28        5.0     0.0        0.0
# ...         ...             ...        ...     ...        ...
# 1938         US      2020-03-26    83836.0  1209.0      681.0
# 1939         US      2020-03-27   101657.0  1581.0      869.0
# 1940         US      2020-03-28   121478.0  2026.0     1072.0
# 1941         US      2020-03-29   140886.0  2467.0     2665.0
# 1942         US      2020-03-30   161807.0  2978.0     5644.0
#
# [1943 rows x 5 columns]

# %%
#df_largest_inf_rates['new'] = df_largest_inf_rates.groupby('Country').cumcount()
#df_largest_inf_rates[df_largest_inf_rates['Country'] == 'Australia']

# %%
def days_since_100_cases(df):
    
    '''Take the latest df, filter for days where country has over
    100 cases, then make new field with count since 100 cases'''

    df_100 = (df
              .query('Confirmed >= 100')
              .sort_values(['Country', 'ObservationDate'])
             )
    
    df_100['Days_since_100'] = df_100.groupby('Country').cumcount()
    df_100 = df_100.reset_index(drop=True)
    
    return(df_100)

# %%
df_since_100 = days_since_100_cases(df_largest_inf_rates)
#df_since_100[df_since_100['Country'] == 'US']
df_since_100.tail()
# Out:
#     Country ObservationDate  Confirmed  Deaths  Recovered  Days_since_100
# 951      US      2020-03-26    83836.0  1209.0      681.0              24
# 952      US      2020-03-27   101657.0  1581.0      869.0              25
# 953      US      2020-03-28   121478.0  2026.0     1072.0              26
# 954      US      2020-03-29   140886.0  2467.0     2665.0              27
# 955      US      2020-03-30   161807.0  2978.0     5644.0              28

# %% [markdown]
# Plot countries' infection growth (where countries currently have over 1000 confirmed cases) from 100 cases onwards

# %%
def growth_comparison_lineplot(df, plot_title, label_cond):
    
    p1 = (p9.ggplot(df, p9.aes('Days_since_100', 'Confirmed'))
     + p9.geoms.geom_line(p9.aes(colour='Country'))
     + p9.geoms.geom_text(mapping=p9.aes(label='Country'),
                          data = label_cond,
                         size=7, nudge_y=1)
     + p9.scales.scale_colour_discrete(guide=False)
     + p9.themes.theme_bw()
     + p9.theme(figure_size=(7,5))
     + p9.labels.labs(title = plot_title,
                     x = "Days since 100 cases",
                     y = 'Number of cases')
    )

    return(p1)

# %%
line_labels = df_since_100[(df_since_100['ObservationDate']==latest_date) & 
            (df_since_100['Country'].isin(['US', 'Mainland China', 'Italy',
                                'France', 'Spain', 'Iran']))]

growth_comparison_lineplot(df_since_100, 
                           "Infection growth for all countries > 1000 cases",
                          line_labels)
# Out:
# <ggplot: (7554265569)>

# %% [markdown]
# Plot countries who's latest infection number is greater than 10,000

# %%
def plot_country_bracket(df, lower_lmt, upper_lmt, title):
    
    df_between = df.groupby('Country').max()
    
    if (lower_lmt > 0 and upper_lmt == 0):
        df_between = df_between[df_between['Confirmed'] >= lower_lmt]
    elif (upper_lmt > 0 and lower_lmt == 0):
        df_between = df_between[df_between['Confirmed'] <= upper_lmt]
    else:
        df_between = df_between[(df_between['Confirmed'] >= lower_lmt) & (df_between['Confirmed'] <= upper_lmt)]    
    
    country_list = list(df_between.index)
    
    df_filtered = df[df['Country'].isin(country_list)]
    
    latest_date = latest_date = str(dt.date.today() - dt.timedelta(days=2))
    line_labels = df_filtered[df_filtered['ObservationDate'] == latest_date]
    growth_plot = growth_comparison_lineplot(df_filtered, 
                                             title,
                                            line_labels)
    
    return(growth_plot)

# %%
plot_country_bracket(df_since_100, 10000, 0, "Countries with 10k+ cases")
# Out:
# <ggplot: (7558567273)>

# %%
plot_country_bracket(df_since_100, 7000, 10000, "Countries with 7k - 10k cases")
# Out:
# <ggplot: (7551661129)>

# %%
plot_country_bracket(df_since_100, 3000, 7000, "Between 3k and 7k cases")
# Out:
# <ggplot: (7551484089)>

# %%
plot_country_bracket(df_since_100, 2000, 3000, "Between 2,000 & 3,000 cases")
# Out:
# <ggplot: (7551797013)>

# %%
plot_country_bracket(df_since_100, 1000, 2000, "Between 1,000 & 2,000 cases")
# Out:
# <ggplot: (7557718421)>

# %% [markdown]
# ## Percentage increase analysis
#
# ### For countries > 1,000 cases, since first 100 cases
#
# Which countries have had the greatest week-on-week percentage increase in cases (i.e. those countries that are struggling to "flatten the curve")

# %% [markdown]
# As there are varying numbers of weeks between countries for days since 100 cases, we will plot four comparison graphs:
#
#  - % increase in first week
#
#  - % increase in second week
#
#  - % increase in first two weeks
#
#  - % increase in the previous week from today

# %%
def percentage_increase_two_weeks(df):
    
    df_checkpoints = (df
                      .query('Days_since_100 == 0\
                      or Days_since_100 == 7\
                      or Days_since_100 == 14')
                      .set_index(['Country','Days_since_100']).Confirmed
                     )
    
    df_grouped_pct_change = pd.DataFrame(df_checkpoints.groupby(['Country']).pct_change())
    df_grouped_pct_change = pd.DataFrame(df_grouped_pct_change.to_records())
    
    df_grouped_pct_change = (df_grouped_pct_change
                            .assign(Pct_increase = df_grouped_pct_change['Confirmed'] * 100)#df_grouped_pct_change[Confirmed] * 100')
                            .drop('Confirmed', axis=1)
                            .fillna(0)
                            )

    return(df_grouped_pct_change)

# %%
df_first_twoWeeks = percentage_increase_two_weeks(df_since_100)
#df_first_twoWeeks = df_first_twoWeeks.rename(columns = {'Confirmed':'Pct_increase'})
df_first_twoWeeks
# Out:
#        Country  Days_since_100  Pct_increase
# 0    Australia               0      0.000000
# 1    Australia               7    322.429907
# 2    Australia              14    352.212389
# 3      Austria               0      0.000000
# 4      Austria               7    726.923077
# ..         ...             ...           ...
# 116         UK               7    299.130435
# 117         UK              14    491.721133
# 118         US               0      0.000000
# 119         US               7    499.009901
# 120         US              14    665.619835
#
# [121 rows x 3 columns]

# %%
def plot_period_increase(df, days_since_100, week_no):
    
    # Filter and order the df for a bar plot
    
    df_week = (df
              .query('Days_since_100 == @days_since_100')
              .sort_values('Pct_increase')
              )

    country_list = df_week['Country'].to_list()
    country_category = pd.Categorical(df_week['Country'],
                                     categories=country_list)
    
    df_week = df_week.assign(country_category=country_category)
    
    
    # Build bar plot
    
    country_week_plot = (p9.ggplot(df_week,
                                   p9.aes(x = 'country_category', y='Pct_increase'))
                         + p9.coords.coord_flip()
                         + p9.geoms.geom_col(stat='identity')
                         + p9.themes.theme_bw()
                         + p9.labels.labs(title = "Percentage increase in cases in {} week".format(week_no),
                                          y = 'Percentage increase')
                        )
    return(country_week_plot)

# %%
plot_period_increase(df_first_twoWeeks, 7, "first")
# Out:
# <ggplot: (7556306809)>

# %%
plot_period_increase(df_first_twoWeeks, 14, "second")
# Out:
# <ggplot: (7552993833)>

# %%
def calc_WoWincrease_change(df):
    
    '''df_filtered = df[df['Days_since_100'] != 0]
    df_pivoted = df_filtered.pivot('Country', 'Days_since_100', 'Pct_increase')
    df_pivoted = df_pivoted.reset_index()
    df_pivoted = df_pivoted.rename(columns = {7:'% increase 1 week after 100 cases',
                                              14:'% increase second week'})
    df_pivoted['WoW_increase_change'] = df_pivoted['% increase second week'] - df_pivoted['% increase 1 week after 100 cases']
    df_pivoted = df_pivoted[df_pivoted['WoW_increase_change'].notnull()]
    '''
    df_wow_filtered = df[df['Days_since_100'] != 0]
    df_wow_pivoted = df_wow_filtered.pivot('Country', 'Days_since_100', 'Pct_increase')
    df_wow_pivoted = (df_wow_pivoted
                      .reset_index()
                      .rename(columns = {7:'perc_increase_week_after_100_cases',
                                        14:'perc_increase_second_week'})
                     )
    df_wow_pivoted['WoW_increase_change'] = 
    df_wow_pivoted['WoW_increase_change'] = 
    
    .assign( = )
    
    
    return(df_wow_pivoted)

# %%
df_wow_change = calc_WoWincrease_change(df_first_twoWeeks)
#df_wow_change.sort_values('WoW_increase_change', ascending=False).head(10)
df_wow_change
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896         By definition, these are labels unless 'iloc' is passed in.
# -> 2897         Floats are not allowed as the start, step, or stop of the slice.
#    2898
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'perc_increase_second_week'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-760-ccd98044712f> in <module>
# ----> 1 df_wow_change = calc_WoWincrease_change(df_first_twoWeeks)
#       2 #df_wow_change.sort_values('WoW_increase_change', ascending=False).head(10)
#       3 df_wow_change
#
# <ipython-input-759-f6e0f4fab588> in calc_WoWincrease_change(df)
#      15                       .rename(columns = {7:'perc_increase_week_after_100_cases',
#      16                                         14:'perc_increase_second_week'})
# ---> 17                       .assign(WoW_increase_change = df_wow_pivoted['perc_increase_second_week'] - df_wow_pivoted['perc_increase_week_after_100_cases'])
#      18                       #.filter()
#      19                       #.query(df_wow_pivoted['WoW_increase_ch'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978
#    2979         if key.values.size and not is_bool_dtype(key.values):
# -> 2980             raise TypeError(
#    2981                 "Must pass DataFrame or 2-d ndarray with boolean values only"
#    2982             )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897         Floats are not allowed as the start, step, or stop of the slice.
#    2898
# -> 2899         Parameters
#    2900         ----------
#    2901         key : label of the slice bound
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'perc_increase_second_week'

# %%
df_wow_change.sort_values('WoW_increase_change', ascending=False).tail(10)
# Out:
# Days_since_100         Country  % increase 1 week after 100 cases  \
# 1                      Austria                         726.923077
# 26                    Pakistan                         543.382353
# 10                      France                         849.000000
# 29                    Portugal                         810.714286
# 36                      Sweden                         705.940594
# 19                       Italy                         992.903226
# 22              Mainland China                        1009.689214
# 25                      Norway                         822.222222
# 34                 South Korea                        1598.076923
# 16                        Iran                        2002.158273
#
# Days_since_100  % increase second week  WoW_increase_change
# 1                           316.279070          -410.644007
# 26                           96.228571          -447.153782
# 10                          372.075869          -476.924131
# 29                          318.431373          -492.282913
# 36                          101.351351          -604.589243
# 19                          335.360094          -657.543131
# 22                          351.548600          -658.140614
# 25                           92.168675          -730.053548
# 34                          244.733862         -1353.343061
# 16                          208.008214         -1794.150060

# %%
# Largest increase in cases over the entire first two-week period since 100 cases
def increase_first_two_weeks(df):
    df_filtered = df[(df['Days_since_100'] == 0) |
                     (df_since_100['Days_since_100'] == 14)]
    
    df_pivot = df_filtered.pivot('Country', 'Days_since_100', 'Confirmed')
    df_pivot = df_pivot.rename(columns = {0:'Week_0',
                                               14: 'Week_2'})
    df_pivot['Increase'] = df_pivot['Week_2'] - df_pivot['Week_0']
    df_pivot['Perc_increase'] = (df_pivot['Increase'] / df_pivot['Week_0']) * 100
    df_pivot = df_pivot[df_pivot['Perc_increase'].notnull()]
    return(df_pivot)

# %%
two_week_increase = increase_first_two_weeks(df_since_100)
two_week_increase.sort_values('Perc_increase', ascending=False)
# Out:
# Days_since_100  Week_0   Week_2  Increase  Perc_increase
# Country
# Spain            120.0   9942.0    9822.0    8185.000000
# Iran             139.0   9000.0    8861.0    6374.820144
# South Korea      104.0   6088.0    5984.0    5753.846154
# Mainland China   547.0  27409.0   26862.0    4910.786106
# Italy            155.0   7375.0    7220.0    4658.064516
# US               101.0   4632.0    4531.0    4486.138614
# France           100.0   4480.0    4380.0    4380.000000
# Germany          130.0   5795.0    5665.0    4357.692308
# Portugal         112.0   4268.0    4156.0    3710.714286
# Switzerland      114.0   4075.0    3961.0    3474.561404
# Austria          104.0   3580.0    3476.0    3342.307692
# Canada           108.0   3251.0    3143.0    2910.185185
# UK               115.0   2716.0    2601.0    2261.739130
# Netherlands      128.0   3003.0    2875.0    2246.093750
# Brazil           151.0   3417.0    3266.0    2162.913907
# Israel           109.0   2369.0    2260.0    2073.394495
# Belgium          109.0   2257.0    2148.0    1970.642202
# Australia        107.0   2044.0    1937.0    1810.280374
# Ireland          129.0   2415.0    2286.0    1772.093023
# Norway           108.0   1914.0    1806.0    1672.222222
# Sweden           101.0   1639.0    1538.0    1522.772277
# Czech Republic   141.0   2279.0    2138.0    1516.312057
# Poland           103.0   1638.0    1535.0    1490.291262
# Chile            155.0   2449.0    2294.0    1480.000000
# Malaysia         117.0   1518.0    1401.0    1197.435897
# Pakistan         136.0   1717.0    1581.0    1162.500000
# Thailand         114.0   1388.0    1274.0    1117.543860
# Romania          123.0   1452.0    1329.0    1080.487805
# Saudi Arabia     103.0   1203.0    1100.0    1067.961165
# Indonesia        117.0   1285.0    1168.0     998.290598
# Philippines      111.0   1075.0     964.0     868.468468
# India            102.0    987.0     885.0     867.647059
# Iceland          103.0    802.0     699.0     678.640777
# Finland          155.0   1041.0     886.0     571.612903
# Denmark          262.0   1718.0    1456.0     555.725191
# Greece           190.0    966.0     776.0     408.421053
# Japan            105.0    420.0     315.0     300.000000

# %%
two_weeks_ago = str(dt.date.today() - dt.timedelta(days=16))
two_weeks_ago

# %%
df_since_100[(df_since_100['ObservationDate'] == two_weeks_ago)|
            (df_since_100['ObservationDate'] == latest_date)]

df_checkpoints = df_checkpoints.set_index(['Country', 'Days_since_100']).Confirmed
    
    df_grouped_pct_change = pd.DataFrame(df_checkpoints.groupby(['Country']).pct_change())
    df_grouped_pct_change = pd.DataFrame(df_grouped_pct_change.to_records())
    df_grouped_pct_change.fillna(0, inplace=True)

# %%
def increase_last_two_weeks(df):
    
    df_last_tw = df[(df['ObservationDate'] == two_weeks_ago)|
            (df['ObservationDate'] == latest_date)]
    df_last_tw = df_last_tw.set_index(['Country']).Confirmed
    
    df_last_tw_pc_change = pd.DataFrame(df_last_tw.groupby(['Country']).pct_change())
    df_last_tw_pc_change = pd.DataFrame(df_last_tw_pc_change.to_records())
    df_last_tw_pc_change = df_last_tw_pc_change[df_last_tw_pc_change['Confirmed'].notnull()]
    df_last_tw_pc_change['Pct_increase'] = df_last_tw_pc_change['Confirmed'] * 100
    df_last_tw_pc_change.drop('Confirmed', axis=1, inplace=True)
    
    return(df_last_tw_pc_change)

# %%
df_last_two_weeks = increase_last_two_weeks(df_since_100).sort_values('Pct_increase', ascending=False)

# %%
(p9.ggplot(df_last_two_weeks,
               p9.aes(x = 'Country', y='Pct_increase'))
     + p9.coords.coord_flip()
     + p9.geoms.geom_col(stat='identity')
     + p9.themes.theme_bw()
     + p9.labels.labs(title = "Percentage increase in cases in last two weeks",
                      y = 'Percentage increase')
    )

# %%
(
    df_since_100
    .query('Confirmed > 200')
    .assign(Pct_increase = 1,
           Another_colum = 2)

)
# Out:
#        Country ObservationDate  Confirmed  Deaths  Recovered  Days_since_100  \
# 4    Australia      2020-03-14      250.0     3.0       23.0               4
# 5    Australia      2020-03-15      297.0     3.0       23.0               5
# 6    Australia      2020-03-16      377.0     3.0       23.0               6
# 7    Australia      2020-03-17      452.0     5.0       23.0               7
# 8    Australia      2020-03-18      568.0     6.0       23.0               8
# ..         ...             ...        ...     ...        ...             ...
# 951         US      2020-03-26    83836.0  1209.0      681.0              24
# 952         US      2020-03-27   101657.0  1581.0      869.0              25
# 953         US      2020-03-28   121478.0  2026.0     1072.0              26
# 954         US      2020-03-29   140886.0  2467.0     2665.0              27
# 955         US      2020-03-30   161807.0  2978.0     5644.0              28
#
#      Pct_increase  Another_colum
# 4               1              2
# 5               1              2
# 6               1              2
# 7               1              2
# 8               1              2
# ..            ...            ...
# 951             1              2
# 952             1              2
# 953             1              2
# 954             1              2
# 955             1              2
#
# [846 rows x 8 columns]
